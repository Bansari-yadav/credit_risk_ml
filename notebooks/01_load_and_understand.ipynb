# %%
import pandas as pd

# Load the dataset
df = pd.read_excel("../data/raw/default of credit card clients.xls")

# Check size
print("Rows, Columns:", df.shape)

# Preview data
df.head()

# %%
# Reload dataset with correct header
df = pd.read_excel(
    "../data/raw/default of credit card clients.xls",
    header=1
)

df.head()
